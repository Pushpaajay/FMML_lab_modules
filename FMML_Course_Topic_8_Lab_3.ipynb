# %% [markdown]
# <a href="https://colab.research.google.com/github/pushpakolli/FMML_lab_modules/blob/main/FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2024-04-02 07:31:34--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.108.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   249MB/s    in 0.3s
#
# 2024-04-02 07:31:35 (249 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 22552  1611.05940v2  We propose a method for finding alternate feat...  stat
# 2401   1604.03853v2  Non-negative matrix factorization models based...    cs
# 21724   1104.5341v2  A linear non-Gaussian structural equation mode...  stat
# 10708   1212.4507v2  We discuss a general technique that can be use...  stat
# 19548   0903.3926v1  Often user interfaces of theorem proving syste...    cs
# ...             ...                                                ...   ...
# 29028  1708.02668v1  While Markov Random Fields (MRFs) are widely u...    cs
# 12005  1706.01498v2  Recent advances in stochastic gradient techniq...  stat
# 15903  1606.05967v1  State of the art speech recognition systems us...    cs
# 14819   1107.4723v2  We describe a new semantic relatedness measure...    cs
# 15664  1601.01280v2  Semantic parsing aims at mapping natural langu...    cs
#
#                                                    title  year  \
# 22552                Finding Alternate Features in Lasso  2016
# 2401         Hierarchical Compound Poisson Factorization  2016
# 21724  Joint estimation of linear non-Gaussian acycli...  2011
# 10708                           Variational Optimization  2012
# 19548  Designing a GUI for Proofs - Evaluation of an ...  2009
# ...                                                  ...   ...
# 29028  A discriminative view of MRF pre-processing al...  2017
# 12005         Stochastic Gradient Monomial Gamma Sampler  2017
# 15903  A Nonparametric Bayesian Approach for Spoken T...  2016
# 14819  A Semantic Relatedness Measure Based on Combin...  2011
# 15664     Language to Logical Form with Neural Attention  2016
#
#                                                 keywords
# 22552  [alternate, resulting, interpreted, alternate,...
# 2401   [factorization, hierarchical, structure, effec...
# 21724  [structural, identifiable, exploratory, variab...
# 10708  [technique, differentiable, differentiable, ob...
# 19548  [interfaces, assisting, particularly, difficul...
# ...                                                  ...
# 29028  [challenging, inference, inference, accelerate...
# 12005  [stochastic, techniques, posterior, distributi...
# 15903  [recognition, intensive, dependent, approaches...
# 14819  [relatedness, combining, wikipedia, collocatio...
# 15664  [interpretable, representations, traditional, ...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 22552    [alternate, resulting, interpreted, alternate,...
# 2401     [factorization, hierarchical, structure, effec...
# 21724    [structural, identifiable, exploratory, variab...
# 10708    [technique, differentiable, differentiable, ob...
# 19548    [interfaces, assisting, particularly, difficul...
#                                ...
# 38755    [pedestrian, movements, capturing, pedestrian,...
# 7635     [selection, validation, essential, validation,...
# 22703    [overlapping, identical, corresponding, modera...
# 10608    [motivation, repositories, experimental, dedic...
# 7422     [predicted, structured, sequences, matchings, ...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8729 words.
# Out of those 4646 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="0d799722-caab-4f97-b784-08c470b4bef3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0d799722-caab-4f97-b784-08c470b4bef3")) {                    Plotly.newPlot(                        "0d799722-caab-4f97-b784-08c470b4bef3",                        [{"x":["reasonable","alternate","computations","interpreted","resulting","efficiently","redundant","demonstrate","distribution","responses","favorable","recommendation","importantly","extremely","filtering","decouples","introduce","effectively","applications","successful","hierarchical","relationship","particular","factorization","scalability","dimensional","expressiveness","structure","continuous","collaborative","strengths","different","differently","distributed","conditions","simulations","estimates","identifiable","estimation","assumption","exploratory","estimating","variables","structural","connection","accurately","separately","application","circumstances","technique","optimization","description","objective","classification","differentiable","variational","functions","construct","designing","experiment","mathematical","describes","particularly","interactive","interfaces","evaluation","assisting","suggestions","interaction","difficult","computation","presented","causality","identifiability","illustrated","graphically","reasoning","intervention","definition","graphical","multivariate","comparable","component","synthetic","multinomial","parameter","experiments","highlighting","exponential","broadening","conditional","capturing","arbitrary","empirically","distributions","generalize","estimator","algorithm","interesting","probability","undirected","dirichlet","sparsistent","specifically","available","attentions","relaxation","nonconvex","stability","effectiveness","distorted","clustering","observations","simultaneously","optimally","addresses","criterion","uninformative","instability","traditional","properties","statistical","developed","computational","performance","information","regularization","numerical","selection","formulate","investigated","derivative","evolution","monotonic","processing","variation","constrained","connections","approximation","optimizer","condition","penalized","compressed","increases","especially","intrinsic","sufficient","decreases","practical","significance","shrinkage","optimizers","monotonically","hyperparameter","understanding","additionally","recognizing","recognition","discriminative","intricate","convincing","frequency","extraction","representation","structures","significantly","advantage","architectures","comparing","convolution","currently","detecting","precision","statistics","otherwise","disparate","dependency","analyzing","individuals","significant","statistically","differential","covariance","theoretically","differentially","longitudinal","parametric","covariates","alzheimers","perspective","dependencies","cognitively","identifying","differences","thresholds","estimated","temporally","technical","increasingly","processes"],"y":[28,5,40,19,147,137,18,564,219,25,14,23,27,57,64,3,319,126,454,83,107,62,270,44,38,175,9,330,110,35,23,768,16,91,132,56,75,3,189,72,7,58,125,73,47,59,36,235,7,228,294,64,147,532,16,48,196,93,44,81,68,84,82,43,12,253,3,4,76,156,150,159,8,6,16,1,134,16,54,38,19,80,111,131,1,119,582,10,34,3,108,40,94,84,107,61,31,826,76,172,14,24,0,176,326,8,19,11,39,197,8,161,84,104,24,65,40,2,6,170,199,153,186,300,926,714,88,63,149,50,48,4,53,12,312,65,68,55,105,3,52,6,28,57,106,38,62,20,126,25,5,0,5,10,134,63,34,401,94,6,8,53,129,359,145,277,91,115,95,45,58,84,74,56,14,4,51,58,39,232,26,26,20,39,6,4,45,2,7,64,48,1,76,51,5,64,15,34,46,109],"type":"bar"},{"x":["reasonable","alternate","computations","interpreted","resulting","effi ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4646,), (4646, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8083333333333333

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Super</span> <span style='background-color:rgba(0, 255, 0, 0.5999999999999999);'>Resolution</span> <span style=''>with</span> <span style=''>Deep</span> <span style='background-color:rgba(0, 255, 0, 0.6008583690987124);'>Convolutional</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Sufficient</span> <span style='background-color:rgba(255, 0, 0, 0.3170731707317074);'>Statistics</span> <br/><br/><span style=''>Inverse</span> <span style=''>problems</span> <span style=''>in</span> <span style=''>image</span> <span style=''>and</span> <span style=''>audio</span> <span style=''>and</span> <span style=''>super</span> <span style='background-color:rgba(0, 255, 0, 0.5999999999999999);'>resolution</span> <span style=''>in</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>particular</span> <span style=''>can</span> <span style=''>be</span> <span style=''>seen</span> <span style=''>as</span> <span style=''>high</span> <span style='background-color:rgba(255, 0, 0, 0.3506493506493507);'>dimensional</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>structured</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>prediction</span> <span style=''>problems</span> <span style=''>where</span> <span style=''>the</span> <span style=''>goal</span> <span style=''>is</span> <span style=''>to</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>characterize</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>conditional</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>distribution</span> <span style=''>of</span> <span style=''>a</span> <span style=''>high</span> <span style='background-color:rgba(0, 255, 0, 0.5999999999999999);'>resolution</span> <span style=''>output</span> <span style=''>given</span> <span style=''>its</span> <span style=''>low</span> <span style='background-color:rgba(0, 255, 0, 0.5999999999999999);'>resolution</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>corrupted</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>observation</span> <span style=''>When</span> <span style=''>the</span> <span style=''>scaling</span> <span style=''>ratio</span> <span style=''>is</span> <span style=''>small</span> <span style=''>point</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>estimates</span> <span style=''>achieve</span> <span style='background-color:rgba(0, 255, 0, 0.5714285714285714);'>impressive</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>performance</span> <span style=''>but</span> <span style=''>soon</span> <span style=''>they</span> <span style=''>suffer</span> <span style=''>from</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.5195071868583163);'>regression</span> <span style=''>to</span> <span style=''>the</span> <span style=''>mean</span> <span style=''>problem</span> <span style=''>result</span> <span style=''>of</span> <span style=''>their</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>inability</span> <span style=''>to</span> <span style=''>capture</span> <span style=''>the</span> <span style=''>multi</span> <span style=''>modality</span> <span style=''>of</span> <span style=''>this</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>conditional</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>distribution</span> <span style=''>Modeling</span> <span style=''>high</span> <span style='background-color:rgba(255, 0, 0, 0.3506493506493507);'>dimensional</span> <span style=''>image</span> <span style=''>and</span> <span style=''>audio</span> <span style='background-color:rgba(255, 0, 0, 0.37058823529411766);'>distributions</span> <span style=''>is</span> <span style=''>a</span> <span style=''>hard</span> <span style=''>task</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>requiring</span> <span style=''>both</span> <span style=''>the</span> <span style=''>ability</span> <span style=''>to</span> <span style=''> ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>STARK</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Structured</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Dictionary</span> <span style=''>Learning</span> <span style=''>Through</span> <span style=''>Rank</span> <span style=''>one</span> <span style=''>Tensor</span> <span style=''>Recovery</span> <br/><br/><span style=''>In</span> <span style=''>recent</span> <span style=''>years</span> <span style=''>a</span> <span style=''>class</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>dictionaries</span> <span style=''>have</span> <span style=''>been</span> <span style=''>proposed</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>multidimensional</span> <span style=''>(tensor)</span> <span style=''>data</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>representation</span> <span style=''>that</span> <span style=''>exploit</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>structure</span> <span style=''>of</span> <span style=''>tensor</span> <span style=''>data</span> <span style=''>by</span> <span style=''>imposing</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Kronecker</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>structure</span> <span style=''>on</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>dictionary</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>underlying</span> <span style=''>the</span> <span style=''>data</span> <span style=''>In</span> <span style=''>this</span> <span style=''>work</span> <span style=''>a</span> <span style=''>novel</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>called</span> <span style=''>STARK</span> <span style=''>is</span> <span style=''>provided</span> <span style=''>to</span> <span style=''>learn</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Kronecker</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>structured</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>dictionaries</span> <span style=''>that</span> <span style=''>can</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>represent</span> <span style=''>tensors</span> <span style=''>of</span> <span style=''>any</span> <span style=''>order</span> <span style=''>By</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>establishing</span> <span style=''>that</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Kronecker</span> <span style=''>product</span> <span style=''>of</span> <span style=''>any</span> <span style=''>number</span> <span style=''>of</span> <span style=''>matrices</span> <span style=''>can</span> <span style=''>be</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>rearranged</span> <span style=''>to</span> <span style=''>form</span> <span style=''>a</span> <span style=''>rank</span> <span style=''>1</span> <span style=''>tensor</span> <span style=''>we</span> <span style=''>show</span> <span style=''>that</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Kronecker</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>structure</span> <span style=''>can</span> <span style=''>be</span> <span style=''>enforced</span> <span style=''>on</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>dictionary</span> <span style=''>by</span> <span style=''>solving</span> <span style=''>a</span> <span style=''>rank</span> <span style=''>1</span> <span style=''>tensor</span> <span style=''>recovery</span> <span style=''>problem</span> <span style=''>Because</span> <span style=''>rank</span> <span style=''>1</span> <span style=''>tensor</span> <span style=''>recovery</span> <span style=''>is</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>challenging</span> <span styl ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Value</span> <span style=''>function</span> <span style='background-color:rgba(255, 0, 0, 0.32475884244372993);'>approximation</span> <span style=''>via</span> <span style=''>low</span> <span style=''>rank</span> <span style=''>models</span> <br/><br/><span style=''>We</span> <span style=''>propose</span> <span style=''>a</span> <span style=''>novel</span> <span style=''>value</span> <span style=''>function</span> <span style='background-color:rgba(255, 0, 0, 0.32475884244372993);'>approximation</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>technique</span> <span style=''>for</span> <span style=''>Markov</span> <span style=''>decision</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>processes</span> <span style=''>We</span> <span style=''>consider</span> <span style=''>the</span> <span style=''>problem</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>compactly</span> <span style='background-color:rgba(0, 255, 0, 0.4);'>representing</span> <span style=''>the</span> <span style=''>state</span> <span style=''>action</span> <span style=''>value</span> <span style=''>function</span> <span style=''>using</span> <span style=''>a</span> <span style=''>low</span> <span style=''>rank</span> <span style=''>and</span> <span style=''>sparse</span> <span style=''>matrix</span> <span style=''>model</span> <span style=''>The</span> <span style=''>problem</span> <span style=''>is</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>decompose</span> <span style=''>a</span> <span style=''>matrix</span> <span style=''>that</span> <span style=''>encodes</span> <span style=''>the</span> <span style=''>true</span> <span style=''>value</span> <span style=''>function</span> <span style=''>into</span> <span style=''>low</span> <span style=''>rank</span> <span style=''>and</span> <span style=''>sparse</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>components</span> <span style=''>and</span> <span style=''>we</span> <span style=''>achieve</span> <span style=''>this</span> <span style=''>using</span> <span style=''>Robust</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Principal</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Component</span> <span style=''>Analysis</span> <span style=''>(PCA)</span> <span style=''>Under</span> <span style=''>minimal</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>assumptions</span> <span style=''>this</span> <span style=''>Robust</span> <span style=''>PCA</span> <span style=''>problem</span> <span style=''>can</span> <span style=''>be</span> <span style=''>solved</span> <span style=''>exactly</span> <span style=''>via</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Principal</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Component</span> <span style=''>Pursuit</span> <span style=''>convex</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>optimization</span> <span style=''>problem</span> <span style=''>We</span> <span style='background-color:rgba(0, 255, 0, 0.48623853211009166);'>experiment</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>procedure</span> <span style=''>on</span> <span style=''>several</span> <span style=''>examples</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>demonstrate</span> <span style=''>that</span> <span style=''>our</span> <span style=''>method</span> <span style=''>yields</span> <span style='background-color:rgba(255, 0, 0, 0.4107142857142858);'>approximations</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>essentially</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>identical</span> <span style=''>to</span> <span style=''>the</span> <span style=''>true</span> <span style=''>function</span> <br/><br/>

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>On</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Robustness</span> <span style=''>of</span> <span style=''>Kernel</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Clustering</span> <br/><br/><span style='background-color:rgba(0, 255, 0, 0.3);'>Clustering</span> <span style=''>is</span> <span style=''>one</span> <span style=''>of</span> <span style=''>the</span> <span style=''>most</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>important</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>unsupervised</span> <span style=''>problems</span> <span style=''>in</span> <span style=''>machine</span> <span style=''>learning</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>statistics</span> <span style=''>Among</span> <span style=''>many</span> <span style=''>existing</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithms</span> <span style=''>kernel</span> <span style=''>k</span> <span style=''>means</span> <span style=''>has</span> <span style=''>drawn</span> <span style=''>much</span> <span style=''>research</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>attention</span> <span style=''>due</span> <span style=''>to</span> <span style=''>its</span> <span style=''>ability</span> <span style=''>to</span> <span style=''>find</span> <span style=''>non</span> <span style=''>linear</span> <span style=''>cluster</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>boundaries</span> <span style=''>and</span> <span style=''>its</span> <span style=''>inherent</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>simplicity</span> <span style=''>There</span> <span style=''>are</span> <span style=''>two</span> <span style=''>main</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>approaches</span> <span style=''>for</span> <span style=''>kernel</span> <span style=''>k</span> <span style=''>means</span> <span style=''>SVD</span> <span style=''>of</span> <span style=''>the</span> <span style=''>kernel</span> <span style=''>matrix</span> <span style=''>and</span> <span style=''>convex</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>relaxations</span> <span style=''>Despite</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>attention</span> <span style=''>kernel</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>clustering</span> <span style=''>has</span> <span style=''>received</span> <span style=''>both</span> <span style=''>from</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>theoretical</span> <span style=''>and</span> <span style=''>applied</span> <span style=''>quarters</span> <span style=''>not</span> <span style=''>much</span> <span style=''>is</span> <span style=''>known</span> <span style=''>about</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>robustness</span> <span style=''>of</span> <span style=''>the</span> <span style=''>methods</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>first</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>introduce</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>semidefinite</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>programming</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>relaxation</span> <span style=''>for</span> <span style=''>the</span> <span style=''>kernel</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>clustering</span> <span style=''>problem</span> <span style=''>then</span> <span style=''>prove</span> <span style=''>that</span> <span style=''>under</span> <span style=''>a</span> <span style=''>suitable</span> <span style=''>model</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>specification</span> <span style=''>both</span> <span style=''>the</span> <span style=''>K</span> <span style=''>SVD</span> ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	experimental (0.13347685683530677)
# 	representation (0.12881234302116973)
# 	segmentation (0.07534983853606028)
# 	processing (0.11194833153928956)
# 	knowledge (0.12809472551130247)
# 	detection (0.1320416218155723)
# 	information (0.25618945102260493)
# 	convolutional (0.1338356655902404)
# 	different (0.2755651237890204)
# 	recognition (0.14388231072838178)
#
# Some Statistics words are:
# 	variational (0.09736711376055639)
# 	stochastic (0.13164431197218082)
# 	theoretical (0.14803775459513163)
# 	estimation (0.16244411326378538)
# 	variables (0.14157973174366617)
# 	statistical (0.15499254843517138)
# 	distribution (0.18181818181818182)
# 	inference (0.20168902136115252)
# 	dimensional (0.18082463984103328)
# 	regression (0.18380526577247888)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="44ee855b-666f-4def-b0f2-ea94d0fda163" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("44ee855b-666f-4def-b0f2-ea94d0fda163")) {                    Plotly.newPlot(                        "44ee855b-666f-4def-b0f2-ea94d0fda163",                        [{"x":["reasonable","alternate","computations","interpreted","resulting","efficiently","redundant","demonstrate","distribution","responses","favorable","recommendation","importantly","extremely","filtering","decouples","introduce","effectively","applications","successful","hierarchical","relationship","particular","factorization","scalability","dimensional","expressiveness","structure","continuous","collaborative","strengths","different","differently","distributed","conditions","simulations","estimates","identifiable","estimation","assumption","exploratory","estimating","variables","structural","connection","accurately","separately","application","circumstances","technique","optimization","description","objective","classification","differentiable","variational","functions","construct","designing","experiment","mathematical","describes","particularly","interactive","interfaces","evaluation","assisting","suggestions","interaction","difficult","computation","presented","causality","identifiability","illustrated","graphically","reasoning","intervention","definition","graphical","multivariate","comparable","component","synthetic","multinomial","parameter","experiments","highlighting","exponential","broadening","conditional","capturing","arbitrary","empirically","distributions","generalize","estimator","algorithm","interesting","probability","undirected","dirichlet","sparsistent","specifically","available","attentions","relaxation","nonconvex","stability","effectiveness","distorted","clustering","observations","simultaneously","optimally","addresses","criterion","uninformative","instability","traditional","properties","statistical","developed","computational","performance","information","regularization","numerical","selection","formulate","investigated","derivative","evolution","monotonic","processing","variation","constrained","connections","approximation","optimizer","condition","penalized","compressed","increases","especially","intrinsic","sufficient","decreases","practical","significance","shrinkage","optimizers","monotonically","hyperparameter","understanding","additionally","recognizing","recognition","discriminative","intricate","convincing","frequency","extraction","representation","structures","significantly","advantage","architectures","comparing","convolution","currently","detecting","precision","statistics","otherwise","disparate","dependency","analyzing","individuals","significant","statistically","differential","covariance","theoretically","differentially","longitudinal","parametric","covariates","alzheimers","perspective","dependencies","cognitively","identifying","differences","thresholds","estimated","temporally","technical","increasingly","processes","important","described","automatically","formalizing","documents","compliance","constraints","implementation","components","noncompliance","implement","generated","environmental","assessment","regulations","assessments","interested","regulatory","published","recordings","variability","belonging","conversations","interviews","scenarios","conversation","equations","considers","modification","approximately","faithfulness","replacing","canonical","predictions","techniques","established","discovery","alternative","influences","situation","interactions","instrumental","posterior","paradoxical","existence","observational","expression","activities","disaggregation","including","accessible","individual","approaches","recoveri ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	sparsistent
# 	optimizers
# 	pronounced
# 	subpopulation
# 	readmission
# 	poisoning
# 	effectivity
# 	consonants
# 	snapshots
# 	neuroscientists
# 	aggregations
# 	marginalization
# 	preconditioned
# 	preconditioning
# 	distributionally
# 	robustification
# 	penalization
# 	frequentist
# 	martingale
# 	dobrushins
# Some words which never appear in Statistics papers:
# 	convincing
# 	formalizing
# 	compliance
# 	equipments
# 	roboticists
# 	achievements
# 	adversarys
# 	abstractions
# 	accelerator
# 	periodical
# 	customised
# 	aggressively
# 	enumerator
# 	dexterous
# 	unconventional
# 	deceptive
# 	allocated
# 	orthography
# 	inflection
# 	grammatical

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.0754090294009104e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.765
